# %%
nombre = 'Alan Hermosilla'
edad = 35
ciudad = 'Lambare'
print(nombre, edad, ciudad)
# Out:
# Alan Hermosilla 35 Lambare

# %%
#CANTIDAD TOTAL DE FRUTAS

cantidad_de_manzanas= 4
cantidad_de_naranjas= 5
#SUMA DE FRUTAS

print(cantidad_de_manzanas + cantidad_de_naranjas)
frutas_vendidas= 3
print(cantidad_de_naranjas + cantidad_de_manzanas-frutas_vendidas)
# Out:
# 9
# 6

# %%
#VARIABLES
#formato de concatenacion poner la f antes de las comillas para poder imprimir, es la mejor forma de hacerlo, las variables deben estar dentro del corchete

nombre= "Thiago"
aperllido= "Vazquez"
print(f"hola, mucho gusto,yo me llamo, {nombre} {aperllido}")
# Out:
# hola, mucho gusto,yo me llamo, Thiago Vazquez

# %%
#solicitar al usuario una accion, en este caso un producto para eso usamos el comoando input

producto = input("Que producto deseas")
print(producto)

#Solictar al usuario que ingrese una cantidad
cantidad_de_producto = input("Que cantdad de producto deseas")
print(cantidad_de_producto)
pront(f"El usuario quiere una{producto} en {cantidad_de_producto} cantidades")

# %%
#solicitar al usario ingresar 2 numeros y almacenarlos en 2 variables. Luego imprimir la suma de los 2 numeros


print("digitar_numero")

numero_2 = (input int("digitar_numero"))
print("digitar_numero")

print(numero + numero_2)
# Out:
#   Cell In[6], line 4
#     numero = (input int("digitar_numero"))
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Ingresar ambos numeros usando input
numero1 = int(input('Ingrese el primer numero'))
numero2 = int(input('Ingrese el segundo numero'))

# Impresion de ambos numeros para saber cuales fueron sumados 
print('El primer numero de la suma fue:', numero1)
print('El segundo numero de la suma fue:', numero2)

# Imprimir la suma de ambos numeros
print(f'Resultado final: {numero1 + numero2}')

# Indicar el tipo de dato de los resultados
print(type(numero1))
print(type(numero2))

# %%
#FUNCION ES UNA INSTRUCIION QUE SE REPITE PARA SOLUCIONAR UN PROBLEMA ESPECIDICO, EN PITON SE ESCRIBE CON LA PALABRA def
#  instruciion(todo los que esta dentro de la funv=cion siempre debe estar indentado

def saludar ():
    print ("hola y bienvenidos")



saludar()
saludar()
saludar()

# %%
def skincare():
    print ("Lavar cara con agua y jabon")
    print ("Secar exceso de agua")
    print ("Aplicar serum")
    print ("Aplicar crema hidratante")
    print ("Aplicar protector solar")
    print ("Listo")

skincare()
skincare()
skincare()

# %%
#Escribir una funcion, que debe tener un parametro que al llamar debetener un argumento que nos pregunte las caractersticas de un elemento a comprar e imprima el elemnto con sus caracteristicas

def comprar_elemento(nombre_elemento):
    # Pedimos características al usuario
    color = input("Ingrese el color del {nombre_elemento}: ")
    tamaño = input("Ingrese el tamaño del {nombre_elemento}: ")
    precio = input("Ingrese el precio del {nombre_elemento}: ")

    comprar_elemento("camisa masculina")


    # Mostramos el resultado
    print("Elemento comprado")
    print("Elemento: {nombre_elemento}")
    print("Color: {color}")
    print("Tamaño: {tamaño}")
    print("Precio: {precio}")

# %%
# Challenge 6
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.

def mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica):
    print(f"El elemento a comprar es {elemento}, y cuenta con las siguientes caracteristicas: {primera_caracteristica}, {segunda_caracteristica}, {tercera_caracteristica}")

def producto_a_comprar():
    elemento = input("Ingrese el elemento a comprar: ")
    primera_caracteristica = input("Ingrese una caracteristica del elemento a comprar: ")
    segunda_caracteristica = input("Ingrese otra caracteristica del elemento a comprar: ")
    tercera_caracteristica = input("Ingrese una ultima caracteristica del elemento a comprar: ")

    mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica)

producto_a_comprar()
# Out:
# El elemento a comprar es auto, y cuenta con las siguientes caracteristicas: nego, caro, aire acondicionado

# %%
def articulo_a_comprar(x, y, z):
    print("Buenas Tardes, que articulo necesitaria")
    print(f'Necesito una {x} de {y} para arreglar mi {z}')
    print('-----------------------------------------------')

especif1= input('Defina el articulo de su eleccion')
especif2= input('Especifique la medida o tipo')
especif3= input('Çuentenos para que lo necesita')

articulo_a_comprar(especif1, especif2, especif3)

articulo_a_comprar('LLave', '3/4', 'moto')
articulo_a_comprar('Lija', '100', 'puerta')
articulo_a_comprar('pintura', 'exterior', 'fachla' \
'ada')

# %% [markdown]
# #ESCRIBIR UNA FUNCION QUE PREGUNTE POR LAS CARACTERISTICAS DE UN PRODUCT0, E IMPRIMA ESE PRODUCTO CON CARACTERSISTICAS IN
# GRESADAS, ADEMAS DEBE TRABAJAR CON CARACTERISTICAS GLOBALES Y LOCALES

# %%
def preguntar_caracteristica(caracteristica):
    valor=input(f"ingrese {caracteristica}")
    print(caracteristica + valor)

articulo=input("ingrese el nombre del producto")
print(f"tu articulo es {articulo}")

preguntar_caracteristica("tipo: ")
preguntar_caracteristica("tamaño: ")
preguntar_caracteristica("color: ")
